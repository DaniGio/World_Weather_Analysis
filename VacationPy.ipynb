# %%
# Import the dependencies.
import pandas as pd

import requests
# Import the API key.
from config import g_key

# %%
import gmaps

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 0        0   Springbok      ZA  2020-02-19 22:04:03 -29.66   17.89     74.46
# 1        1     Kavieng      PG  2020-02-19 22:04:03  -2.57  150.80     82.87
# 2        2    Cherskiy      RU  2020-02-19 22:01:39  68.75  161.30    -23.91
# 3        3     Kabompo      ZM  2020-02-19 22:04:04 -13.59   24.20     66.02
# 4        4  Port Blair      IN  2020-02-19 22:03:24  11.67   92.75     79.54
#
#    Humidity  Cloudiness  Wind Speed
# 0        49          37        7.63
# 1        71          39        8.59
# 2        94          99        6.22
# 3        95          73        0.34
# 4        85          44       12.64

# %%
#Get data type
city_data_df.dtypes
# Out:
# City_ID         int64
# City           object
# Country        object
# Date           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# dtype: object

# %%
# Configure gmaps to use your Google API key.
gmaps.configure(api_key=g_key)

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# ---------------------------------------------------------------------------
# InvalidWeightException                    Traceback (most recent call last)
# <ipython-input-16-85c96b2e684d> in <module>
#       7 fig = gmaps.figure()
#       8 # Assign the heatmap variable.
# ----> 9 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp)
#      10 # Add the heatmap layer.
#      11 fig.add_layer(heat_layer)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     267     )
#     268     if is_weighted:
# --> 269         return WeightedHeatmap(**widget_args)
#     270     else:
#     271         return Heatmap(**widget_args)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ipywidgets/widgets/widget.py in __init__(self, **kwargs)
#     410         """Public constructor"""
#     411         self._model_id = kwargs.pop('model_id', None)
# --> 412         super(Widget, self).__init__(**kwargs)
#     413
#     414         Widget._call_widget_constructed(self)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __init__(self, *args, **kwargs)
#     995             for key, value in kwargs.items():
#     996                 if self.has_trait(key):
# --> 997                     setattr(self, key, value)
#     998                 else:
#     999                     # passthrough args that don't set traits to super
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/gmaps/geotraitlets.py in validate(self, obj, value)
#      49                 raise InvalidWeightException(
#      50                     '{} is not a valid weight. '
# ---> 51                     'Weights must be non-negative.'.format(weight)
#      52                 )
#      53         return super(WeightArray, self).validate(obj, weights)
#
# InvalidWeightException: -23.91 is not a valid weight. Weights must be non-negative.

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]

temps = []
for temp in max_temp:
    temps.append(max(temp, 0))
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=temps)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=[max(temp, 0) for temp in max_temp])



# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = city_data_df[["Lat", "Lng"]]
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
# Assign the figure variable.
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
# Assign the heatmap variable.

heat_layer = gmaps.heatmap_layer(locations, weights=temps, dissipating=False, max_intensity=300, point_radius=4)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent humidity
locations = city_data_df[["Lat", "Lng"]]
humidity = city_data_df["Humidity"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent cloudiness
locations = city_data_df[["Lat", "Lng"]]
clouds = city_data_df["Cloudiness"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=clouds, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Heatmap of percent Wind Speed
locations = city_data_df[["Lat", "Lng"]]
wind = city_data_df["Wind Speed"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=wind, dissipating=False, max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
#Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
# Filter the dataset to find the cities that fit the criteria.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]
preferred_cities_df.head(10)
# Out:
#     City_ID        City Country                 Date    Lat     Lng  Max Temp  \
# 1         1     Kavieng      PG  2020-02-19 22:04:03  -2.57  150.80     82.87
# 4         4  Port Blair      IN  2020-02-19 22:03:24  11.67   92.75     79.54
# 17       17       Vaini      TO  2020-02-19 22:00:48 -21.20 -175.20     80.60
# 21       21     Rikitea      PF  2020-02-19 22:04:11 -23.12 -134.97     78.71
# 24       24    Moranbah      AU  2020-02-19 22:04:13 -22.00  148.05     78.78
# 28       28     Itarema      BR  2020-02-19 22:04:15  -2.92  -39.92     77.00
# 31       31   Kavaratti      IN  2020-02-19 22:00:25  10.57   72.64     81.07
# 34       34    Sandakan      MY  2020-02-19 22:04:07   5.84  118.12     80.60
# 35       35   Hithadhoo      MV  2020-02-19 22:00:05  -0.60   73.08     82.76
# 37       37  Georgetown      MY  2020-02-19 22:04:19   5.41  100.34     77.00
#
#     Humidity  Cloudiness  Wind Speed
# 1         71          39        8.59
# 4         85          44       12.64
# 17        69          20        9.17
# 21        79           6       13.38
# 24        82           0        4.12
# 28       100          75        6.93
# 31        66           0        4.85
# 34        83          20       11.41
# 35        81          98       16.40
# 37        73          20        4.70

# %%
preferred_cities_df.count()
# Out:
# City_ID       176
# City          176
# Country       176
# Date          176
# Lat           176
# Lng           176
# Max Temp      176
# Humidity      176
# Cloudiness    176
# Wind Speed    176
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp    Lat     Lng Hotel Name
# 1      Kavieng      PG     82.87  -2.57  150.80
# 4   Port Blair      IN     79.54  11.67   92.75
# 17       Vaini      TO     80.60 -21.20 -175.20
# 21     Rikitea      PF     78.71 -23.12 -134.97
# 24    Moranbah      AU     78.78 -22.00  148.05
# 28     Itarema      BR     77.00  -2.92  -39.92
# 31   Kavaratti      IN     81.07  10.57   72.64
# 34    Sandakan      MY     80.60   5.84  118.12
# 35   Hithadhoo      MV     82.76  -0.60   73.08
# 37  Georgetown      MY     77.00   5.41  100.34

# %%
# Set parameters to search for a hotel.
params = {
    "radius": 5000,
    "type": "lodging",
    "key": g_key
}

# %%
    # Make request and get the JSON data from the search.
import json
hotels = requests.get(base_url, params=params).json()
print(json.dumps(hotels,indent=2))
# Out:
# {
#   "html_attributions": [],
#   "next_page_token": "CqQCHgEAAAr66LoPK-oH698so--sxzYw2cPCtwwKUObC-5nH-GARCQdPB0S6DwFE5vk9f2J5BDaYjmE80Uxz4NsA26Kzf5SkVaBIdVRbvKlQ6JVplol96yeR97yu6fm1Eom0MJUg-8nNVIEZGJEA11vbg3cFReyfx6iRzX0LiG7sWNIRSTblrK2H1seMsvMV8Lvj8BllqcOL0rTQV6PsNFbLfvCqSN8cGq-PxhEvIFJM95wmdwpA4KJ8hnlA7siMOdtn0TedBUN9FBy0Zs-6OkCnBWnPsFAROyXhMi4q5HlhxXkpqSeRzST2FLP2l4K_712AI_wmd4fgml59e_m8OpRtW1MD-0HtCb2t4DWo1lDVSC-0MispmSdGGXDPT2zd8HVghTjh0RIQORhT1gz-1GuvujV5jM5CKxoUJKboTG4fV4vCOjncItcqIsktlhE",
#   "results": [
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.109631799999999,
#           "lng": 124.8901973
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.108163669708498,
#             "lng": 124.8915648302915
#           },
#           "southwest": {
#             "lat": -9.110861630291502,
#             "lng": 124.8888668697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "d3bd1a021568d6189f7570088472de1361210e7f",
#       "name": "Pondok Pesantren Al Muhajirin Atambua",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 2570,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/117847520437012196260\">Showina Chanel</a>"
#           ],
#           "photo_reference": "CmRaAAAAmV9fv8SlF3iao4MvdFf2hv9h1Ut5qXFeNY7SFe9vF4RSeV3qx4pVDXoC7RyUg3NoQ3S9Ccx0DtVZao2JBQzayXvMEy223FaeoFBPhCy63P1h6VlYNBXdplnxNWDSoFx5EhCJwkXl69njMl1F3s7g9XDnGhSYa6Zj1irrpE5708awtBlDvZFdnw",
#           "width": 2074
#         }
#       ],
#       "place_id": "ChIJ44kx9HG-_ywRDjmAZurpqf4",
#       "plus_code": {
#         "compound_code": "VVRR+43 Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVRR+43"
#       },
#       "rating": 4.5,
#       "reference": "ChIJ44kx9HG-_ywRDjmAZurpqf4",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 10,
#       "vicinity": "Beirafu"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1104766,
#           "lng": 124.8915673
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.109115019708499,
#             "lng": 124.8931050302915
#           },
#           "southwest": {
#             "lat": -9.111812980291504,
#             "lng": 124.8904070697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "9a35040d67830866cfce68bba100289e6be5a53b",
#       "name": "Penginapan Alam Subur",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 1836,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/110787303625145229366\">Ani Eva</a>"
#           ],
#           "photo_reference": "CmRaAAAAVkl0dL3vu7WHI5CgmF1mlYHGdyHYFrvDRDhFj3u0eKqf17Q3adjPKIzMaGW6jr2XtmF71dOvbhmW5C_dKPC1lUaBIkLspY4OvlQsSch65kLRMw0FCuSuxjJjZALEEC-kEhACT66BCqw3zQ71ZzVsrdIKGhS8T5VLqtw-v7jrVpZMFQ2WuE7SlA",
#           "width": 3264
#         }
#       ],
#       "place_id": "ChIJwayro3G-_ywRmTW88U7mb7k",
#       "plus_code": {
#         "compound_code": "VVQR+RJ Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVQR+RJ"
#       },
#       "rating": 4.1,
#       "reference": "ChIJwayro3G-_ywRmTW88U7mb7k",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 83,
#       "vicinity": "Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.110877499999997,
#           "lng": 124.8915287
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.109568119708497,
#             "lng": 124.8927936302915
#           },
#           "southwest": {
#             "lat": -9.112266080291501,
#             "lng": 124.8900956697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "f66f7ff92022a9c3d7d489b3e6be21d6271ee736",
#       "name": "Hotel Alam Subur",
#       "photos": [
#         {
#           "height": 4208,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/111981821439214064404\">Guyub Manggala K</a>"
#           ],
#           "photo_reference": "CmRaAAAAtWu9AXICYjWsFlUiY6G_gCjvbKa-RpFsCzuF6hlc-uGH9dWi4HWHcwpQFq2tLWy9sqym3bB2OxuTOBbe3hACoClRDDlm6aAy89rsX5iAZtIB_JvG1OOrKXYAtOb_LVKEEhAfUeAGiDvSTpIznW-fdcOVGhQGs2-ls5Em_ekTZY3Sc6Tib75MRw",
#           "width": 3120
#         }
#       ],
#       "place_id": "ChIJOUZ7oHG-_ywRkqQo8zrF2b4",
#       "plus_code": {
#         "compound_code": "VVQR+JJ Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVQR+JJ"
#       },
#       "rating": 4,
#       "reference": "ChIJOUZ7oHG-_ywRkqQo8zrF2b4",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 9,
#       "vicinity": "Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.109617199999997,
#           "lng": 124.886693
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.108341269708495,
#             "lng": 124.8880710302915
#           },
#           "southwest": {
#             "lat": -9.1110392302915,
#             "lng": 124.8853730697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "485eb9bb240d9002dac9042cf3004e8b8cfaa9f5",
#       "name": "Kos orange",
#       "place_id": "ChIJX5KPmCW__ywRf8Vsrn6kKEQ",
#       "plus_code": {
#         "compound_code": "VVRP+5M Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVRP+5M"
#       },
#       "rating": 5,
#       "reference": "ChIJX5KPmCW__ywRf8Vsrn6kKEQ",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 1,
#       "vicinity": "Beirafu"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1128327,
#           "lng": 124.8917433
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.111441269708498,
#             "lng": 124.8929957302915
#           },
#           "southwest": {
#             "lat": -9.114139230291503,
#             "lng": 124.8902977697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "260ddbf94add768cb1295c65d4455b61f86afe25",
#       "name": "Yustina Ratudabbo",
#       "photos": [
#         {
#           "height": 1080,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/100520098513776944877\">Defro Koelima</a>"
#           ],
#           "photo_reference": "CmRaAAAAHPSlWgAQY_MKR2GFZ0tWpGXoID3oo0xI1I1vBoy_wQWUQpBfAQ8DKhAsMdqpf6K-F91CO-RtxuVEuuVpRpr-LU6oNrhNbig_Lw7BUcZzxUNyt8AJB4MIGOP757HoTCBLEhBYPceqE9QooRNZOJ9A1B1yGhS5IXBb5bpiMrjZmU37n27P4ssYfA",
#           "width": 1920
#         }
#       ],
#       "place_id": "ChIJDSqZdIS__ywRdxJQJNPjzoo",
#       "plus_code": {
#         "compound_code": "VVPR+VM Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPR+VM"
#       },
#       "reference": "ChIJDSqZdIS__ywRdxJQJNPjzoo",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Muhammad Yamin No.45, Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1139645,
#           "lng": 124.8898632
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.112579669708499,
#             "lng": 124.8912343302915
#           },
#           "southwest": {
#             "lat": -9.115277630291503,
#             "lng": 124.8885363697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "4821ea22508233811a4eebb52146a5eeddc0d081",
#       "name": "Kost ,kuburan islam",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 1920,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/105647795744981560519\">Odrick Ati</a>"
#           ],
#           "photo_reference": "CmRaAAAAgcQobTS37MJzGhqHnP32zdmcwAgnoWsW61q82DoZ9ffvCxBRkZLQ3jay965yayUKAjuMRdLUilL8-Wnz4yNAtzEmSnrilKQ_RxveBF-FUYIKdqJpvwP77HWekr-rtn76EhAMQI5wUGVQ4kouY1aT85YbGhQBru9GgMuWPOKhOgN7-QqidNsodQ",
#           "width": 1080
#         }
#       ],
#       "place_id": "ChIJDV8_iyW__ywRsPx0zAi_tLE",
#       "plus_code": {
#         "compound_code": "VVPQ+CW Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPQ+CW"
#       },
#       "reference": "ChIJDV8_iyW__ywRsPx0zAi_tLE",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1131895,
#           "lng": 124.88732
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.111854619708499,
#             "lng": 124.8887369802915
#           },
#           "southwest": {
#             "lat": -9.114552580291504,
#             "lng": 124.8860390197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "3c27e4fd2735fc6c124eb608a618ee1dee6ab7cd",
#       "name": "Rumah Bpk. Paulus Bere",
#       "photos": [
#         {
#           "height": 712,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/101566248754710394429\">Ama Bere</a>"
#           ],
#           "photo_reference": "CmRaAAAA2rEtEFa1e1_RolKD-hK2OpXHbnplKA1QNMeDfTRFQwCEA3vyhwC-yDJjxdnMYRhzXlrFXn3OqdwHojRhb3xa5d4388QbiuDBA4K6zCajOp1YgYIl_lT2FXfFOt6dJq6TEhBuWOpqLr1G-YoAEQplUShWGhTNTblYk439rMPC2OjFIBcjMSS_XQ",
#           "width": 712
#         }
#       ],
#       "place_id": "ChIJn3Y8z7a__ywRJFXzZP7-Owg",
#       "plus_code": {
#         "compound_code": "VVPP+PW Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPP+PW"
#       },
#       "reference": "ChIJn3Y8z7a__ywRJFXzZP7-Owg",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Manuaman"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.114068399999997,
#           "lng": 124.8880813
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.112695419708498,
#             "lng": 124.8894843302915
#           },
#           "southwest": {
#             "lat": -9.115393380291502,
#             "lng": 124.8867863697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "a9f6204c244d2e895d26c4b98cb6ed72cc6ff13f",
#       "name": "Panti asuhan",
#       "place_id": "ChIJuQ9q0A2__ywRBwwasOvjpjA",
#       "plus_code": {
#         "compound_code": "VVPQ+96 Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPQ+96"
#       },
#       "reference": "ChIJuQ9q0A2__ywRBwwasOvjpjA",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1146549,
#           "lng": 124.8909234
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.113241619708498,
#             "lng": 124.8921595802915
#           },
#           "southwest": {
#             "lat": -9.115939580291503,
#             "lng": 124.8894616197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "14dffaac5d414ffcda608cefe54c8aaa180d5269",
#       "name": "Kost Puput Gladys",
#       "place_id": "ChIJL26H7l2__ywRI6OuEULwhKk",
#       "plus_code": {
#         "compound_code": "VVPR+49 Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPR+49"
#       },
#       "reference": "ChIJL26H7l2__ywRI6OuEULwhKk",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Raya Atambua No.Km, RW.2, Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1146549,
#           "lng": 124.8909234
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.113241619708498,
#             "lng": 124.8921595802915
#           },
#           "southwest": {
#             "lat": -9.115939580291503,
#             "lng": 124.8894616197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "a14fb2e21b6b8525765aa1d99d8256a4b70a4423",
#       "name": "Hotel King Star",
#       "opening_hours": {
#         "open_now": true
#       },
#       "photos": [
#         {
#           "height": 1960,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/107336599332503587199\">Hotel King Star</a>"
#           ],
#           "photo_reference": "CmRaAAAAQ6k3HNm1S-SpL9rgmEzAoithYPHLWcT8N0cSftqkT4pL7D4pxjqGw-rhu3PXRA82eDp5j033v5NUCy7GU-XWLOiXyJDbuw5_IdlZ4qepu3QqUlMkEcF0NprXzKWFg-H7EhCwO9cbbjIwS4-TyFbaQ2UmGhSKj5Gk7Q8lXAKE4qJYxFgGb5eHTg",
#           "width": 4032
#         }
#       ],
#       "place_id": "ChIJhaVOlna-_ywRo3tJn5pR8mc",
#       "plus_code": {
#         "compound_code": "VVPR+49 South Atambua, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPR+49"
#       },
#       "rating": 4,
#       "reference": "ChIJhaVOlna-_ywRo3tJn5pR8mc",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 292,
#       "vicinity": "Jalan Raya Atambua No.Km. 2, Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1146549,
#           "lng": 124.8909234
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.113241619708498,
#             "lng": 124.8921595802915
#           },
#           "southwest": {
#             "lat": -9.115939580291503,
#             "lng": 124.8894616197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "43eef387fe76e3e1c85473a6d5a05c47953ac550",
#       "name": "KOST PUPUT GLADYS ATAMBUA",
#       "place_id": "ChIJ27_nUNi__ywRc4zS30haBGg",
#       "plus_code": {
#         "compound_code": "VVPR+49 Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPR+49"
#       },
#       "reference": "ChIJ27_nUNi__ywRc4zS30haBGg",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Depan Hotel King Star, Jalan Muhammad Yamin No.KM.2"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1090895,
#           "lng": 124.8948759
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.107787519708497,
#             "lng": 124.8962356302915
#           },
#           "southwest": {
#             "lat": -9.110485480291501,
#             "lng": 124.8935376697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "0a3e3ea34784f9e4461071aefd875fc1efc63f11",
#       "name": "Kos cheline",
#       "place_id": "ChIJX7qBI9e__ywReoHYqMBMdzU",
#       "plus_code": {
#         "compound_code": "VVRV+9X Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVRV+9X"
#       },
#       "reference": "ChIJX7qBI9e__ywReoHYqMBMdzU",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Timtim"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.105460599999999,
#           "lng": 124.8871182
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.103948269708498,
#             "lng": 124.8884021302915
#           },
#           "southwest": {
#             "lat": -9.106646230291503,
#             "lng": 124.8857041697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "940dcd40d09c5dcf9244ce4c3e10397d42ba744e",
#       "name": "Hotel Matahari",
#       "photos": [
#         {
#           "height": 2988,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/103376265220419841171\">novi detianta</a>"
#           ],
#           "photo_reference": "CmRaAAAAy7opHxYNS6izJQGHBWZtOQlqzlr4Y7ZOWuP-GTUd9PLTenYiRoIicdi01HDscDZEbNypSrlfw02o5wgWM88LJu9Otd_Tibnm6v8H2Sp-C5RBR7zXj0YYxFXGg8C8ya81EhBgLH9_zgDcm6y8dbti1LjUGhS_mlmk6EQei7SA69dBYeAAgi579A",
#           "width": 5312
#         }
#       ],
#       "place_id": "ChIJf1lgiWy-_ywRLqJQLoM5r5s",
#       "plus_code": {
#         "compound_code": "VVVP+RR West Atambua, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVVP+RR"
#       },
#       "rating": 3.8,
#       "reference": "ChIJf1lgiWy-_ywRLqJQLoM5r5s",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 617,
#       "vicinity": "Jalan Ade Irma Suryani, Beirafu"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.106017399999997,
#           "lng": 124.8863484
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.104680069708495,
#             "lng": 124.8876505802915
#           },
#           "southwest": {
#             "lat": -9.1073780302915,
#             "lng": 124.8849526197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "16854f1d3ad82b4f1c5dc7f95fef2f677cce2ec4",
#       "name": "Nusantara II Hotel",
#       "photos": [
#         {
#           "height": 2988,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/102242412607824262231\">Ry Ri</a>"
#           ],
#           "photo_reference": "CmRaAAAAT2zXvWJPYV-srQiCbC_kYqJZoRdQYwXegyh3IqZb16kCmGz4tdY7gKL8MuMsQDhi3EnDIh6xFtRne6FjyMwq0t61EnnMRjj9rD8HBttPmK6MJ2xxc12B5ivK9yzwzLNeEhBT-G2t-GVl4NvROQwlvT1yGhSw9ufmgxIMFRQPu4Z0_nzF2Y7SWg",
#           "width": 5312
#         }
#       ],
#       "place_id": "ChIJnW-KbTm-_ywRnt5NW54wsBM",
#       "plus_code": {
#         "compound_code": "VVVP+HG Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVVP+HG"
#       },
#       "rating": 3.4,
#       "reference": "ChIJnW-KbTm-_ywRnt5NW54wsBM",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 182,
#       "vicinity": "JL IJ Kasimo, Tulamalae, Umanen"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1147101,
#           "lng": 124.8870277
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.113372719708497,
#             "lng": 124.8884744802915
#           },
#           "southwest": {
#             "lat": -9.116070680291502,
#             "lng": 124.8857765197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "d08c83cf4a7ba6945c35a936121204b4e7b3f300",
#       "name": "Homestay Kemuning",
#       "photos": [
#         {
#           "height": 1280,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/108897363196694561147\">Nonsy Djatmiko</a>"
#           ],
#           "photo_reference": "CmRaAAAAYSnYhidlHmCGpebIio8imcDDORI7ndtQi33uYojdGzBuah2zflJFQhJGD3f_iudrXRXvTZ5GypNwdOVyoWz7P-BNGTBlbJDDw1j0voZFKXhJdwCA6IsYz4eSJ5cJlubeEhDHq2B9n7yUcfmvQYnhZ23QGhSWDFgRrnwCi0ADNEaspPuuauaY0Q",
#           "width": 959
#         }
#       ],
#       "place_id": "ChIJIy9ZEA-__ywRckx66K_9wsk",
#       "plus_code": {
#         "compound_code": "VVPP+4R South Atambua, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVPP+4R"
#       },
#       "reference": "ChIJIy9ZEA-__ywRckx66K_9wsk",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "bengkel Las Merdeka, Jalan I. J. Kasimo No.Depan, Manuaman"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.108152400000002,
#           "lng": 124.8845299
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.106834869708496,
#             "lng": 124.8858776302915
#           },
#           "southwest": {
#             "lat": -9.109532830291501,
#             "lng": 124.8831796697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "2808c60e8aeee87c4cb0eac9d3bd68b3be7ffb74",
#       "name": "Depan Toko Kity",
#       "place_id": "ChIJ5_-nSm2-_ywRtv8KQiBDP1U",
#       "plus_code": {
#         "compound_code": "VVRM+PR Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVRM+PR"
#       },
#       "rating": 3.5,
#       "reference": "ChIJ5_-nSm2-_ywRtv8KQiBDP1U",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 2,
#       "vicinity": "Jalan Saudale No.4, Beirafu"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.108152400000002,
#           "lng": 124.8845299
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.106834869708496,
#             "lng": 124.8858776302915
#           },
#           "southwest": {
#             "lat": -9.109532830291501,
#             "lng": 124.8831796697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "d67ca6c046a27facc8e9708502f67e64e856cc5c",
#       "name": "Kos Kosan",
#       "photos": [
#         {
#           "height": 4128,
#           "html_attributions": [
#             "<a href=\"https://maps.google.com/maps/contrib/106996097486381902540\">adi wibowo</a>"
#           ],
#           "photo_reference": "CmRaAAAACdw6NF7n5Gqb3F-y_ZS5qHoPTEnNgVyLeeSQHsRb00L36gm7xSnfFigKpf-l6MTGsksNW1LHn9a-cjNOyDbgyEQe6i0QxK5ua7ncVn53MOpbj1NAcndXeMULZtjgay9NEhBygSUFw6gucSw3HAaE4ZKzGhR9IzvW0iiLnbdCwzTXPLtcvM6mNA",
#           "width": 3096
#         }
#       ],
#       "place_id": "ChIJ5_-nSm2-_ywRIPHoahR8URQ",
#       "plus_code": {
#         "compound_code": "VVRM+PR Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVRM+PR"
#       },
#       "rating": 4.1,
#       "reference": "ChIJ5_-nSm2-_ywRIPHoahR8URQ",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "user_ratings_total": 18,
#       "vicinity": "Jalan Saudale, Beirafu"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1164344,
#           "lng": 124.8895399
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.1151490697085,
#             "lng": 124.8910537302915
#           },
#           "southwest": {
#             "lat": -9.117847030291502,
#             "lng": 124.8883557697085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "9c9ec79e91f58ea47db5e6cfd0a9cb57777594e7",
#       "name": "Ovi Seubelan",
#       "place_id": "ChIJFY1C93m__ywRYfQ63gmqPeE",
#       "plus_code": {
#         "compound_code": "VVMQ+CR Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVMQ+CR"
#       },
#       "reference": "ChIJFY1C93m__ywRYfQ63gmqPeE",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Raya Atambua, Rinbesi"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1059687,
#           "lng": 124.8957502
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.104570119708498,
#             "lng": 124.8970334802915
#           },
#           "southwest": {
#             "lat": -9.107268080291503,
#             "lng": 124.8943355197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "0df22c419d29949059e93c7dfa8dfa2c52786eb9",
#       "name": "Hotel paradiso",
#       "place_id": "ChIJfexEXRa__ywRrYHCfmEhDRw",
#       "plus_code": {
#         "compound_code": "VVVW+J8 Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVVW+J8"
#       },
#       "reference": "ChIJfexEXRa__ywRrYHCfmEhDRw",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Soekarno - Hatta No.124"
#     },
#     {
#       "geometry": {
#         "location": {
#           "lat": -9.1034676,
#           "lng": 124.8874105
#         },
#         "viewport": {
#           "northeast": {
#             "lat": -9.101849419708499,
#             "lng": 124.8886207802915
#           },
#           "southwest": {
#             "lat": -9.104547380291503,
#             "lng": 124.8859228197085
#           }
#         }
#       },
#       "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#       "id": "afe30fed1cb1878011104968327cca1aee1ceec3",
#       "name": "Menfit Liunima",
#       "place_id": "ChIJATSCrrO__ywR5rELLo_33MM",
#       "plus_code": {
#         "compound_code": "VVWP+JX Atambua, Berdao, Belu Regency, East Nusa Tenggara, Indonesia",
#         "global_code": "6Q26VVWP+JX"
#       },
#       "reference": "ChIJATSCrrO__ywR5rELLo_33MM",
#       "scope": "GOOGLE",
#       "types": [
#         "lodging",
#         "point_of_interest",
#         "establishment"
#       ],
#       "vicinity": "Jalan Dr. G. A. Siwabessyy No.2, Beirafu"
#     }
#   ],
#   "status": "OK"
# }

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    
        
# Grab the first hotel from the results and store the name.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        print("success")
    except IndexError as e:
        print(e)
        
        
        
# Grab the first hotel from the results and store the name.
  try:
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
  except (IndexError):
    print("Hotel not found... skipping.")
# Out:
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success
# success
# list index out of range
# success
# success
# success
# success
# success
# success

# %%
hotel_df
# Out:
#             City Country  Max Temp    Lat     Lng  \
# 1        Kavieng      PG     82.87  -2.57  150.80
# 4     Port Blair      IN     79.54  11.67   92.75
# 17         Vaini      TO     80.60 -21.20 -175.20
# 21       Rikitea      PF     78.71 -23.12 -134.97
# 24      Moranbah      AU     78.78 -22.00  148.05
# ..           ...     ...       ...    ...     ...
# 590       Jimani      DO     89.60  18.49  -71.85
# 592       Palmas      BR     81.86 -10.21  -48.36
# 593  Salinopolis      BR     78.64  -0.61  -47.36
# 598      Yeppoon      AU     84.20 -23.13  150.73
# 600      Atambua      ID     75.07  -9.11  124.89
#
#                                 Hotel Name
# 1                      Nusa Island Retreat
# 4                Fortune Resort Bay Island
# 17                     Keleti Beach Resort
# 21                          Pension Maro'i
# 24       Direct Hotels - Monterey Moranbah
# ..                                     ...
# 590                         HOTEL LA TORRE
# 592                    Hotel Lago da Palma
# 593                      Hotel Salinópolis
# 598                       Villa Mar Colina
# 600  Pondok Pesantren Al Muhajirin Atambua
#
# [176 rows x 6 columns]

# %%
# Add a heatmap of temperature for the vacation spots.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False,
             max_intensity=300, point_radius=4)

fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Add a heatmap of temperature for the vacation spots and marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, 
             dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# Store the DataFrame Row.
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# Add a heatmap of temperature for the vacation spots and a pop-up marker for each city.
locations = hotel_df[["Lat", "Lng"]]
max_temp = hotel_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
